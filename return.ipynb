# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

sp500 = yf.Ticker("^SPX").history(period="1y")

df2 = pd.read_excel("Historia wycen 1685116447322.xlsx")


plt.figure()
plt.subplot(2, 1, 1)
df2[df2.columns[1]].plot(grid=True)



plt.subplot(2, 1, 2)
sp500['Close'].plot(grid=True)
# Out:
# <Axes: xlabel='Date'>
